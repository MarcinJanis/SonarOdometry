# %% [markdown]
# # Feature extractor and Patchifier test

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys

import cv2

import numpy as np 

import torch
import torch.nn as nn
import torch.nn.functional as F

from box import Box
import yaml

import matplotlib.pyplot as plt

from scipy.spatial.transform import Rotation as R
import random 

import time 

root_dir = os.path.abspath('../..')
if root_dir not in sys.path:
    sys.path.append(root_dir)

from src.models.dpso_inference import DPSO
from src.models.encoders import Encoder
from src.models.patchifier import Patchifier
# from src.data_loader.evaluation_data_generator import DataGenerator
from src.data_loader.data_module_lightning import SonarSimDataModule

# %%
model_config_pth = 'C:/Users/janis/Projekty/Magisterka/SonarOdometry/config/model.yaml'
sonar_config_pth = 'C:/Users/janis/Projekty/Magisterka/SonarOdometry/config/sonar.yaml'
train_config_pth = 'C:/Users/janis/Projekty/Magisterka/SonarOdometry/config/training.yaml'


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# root_dir = 'C:/Users/janis/Projekty/Magisterka/SonarOdometry/data'
data_root_dir = 'C:/Users/janis/Projekty/Magisterka/SonarOdometry/SonarOdometryDataset/selfsupervised'
batch_size =  1
num_workers = 0
transforms = None
dm = SonarSimDataModule(data_root_dir, batch_size, batch_size, num_workers, transforms, 15, (800, 768))

dm.setup(stage='fit')
train_data_loader = dm.val_dataloader()

batch = next(iter(train_data_loader))
frames, time, trajectory, depth = batch

print('Input data format')
print(f'time: {time.shape}')
print(f'fls frame: {frames.shape}')
print(f'pose: {trajectory.shape}')
print(f'depth: {depth.shape}')
# Out:
# Input data format
# time: torch.Size([1, 15, 1])
# fls frame: torch.Size([1, 15, 1, 800, 768])
# pose: torch.Size([1, 15, 7])
# depth: torch.Size([1, 15, 1])

# %% [markdown]
# ## 1. Encoder test

# %% [markdown]
# Encoder is responsible for extraction of features or context map from fls frame.

# %%
# instance of encoder 
model_encoder = Encoder(in_ch = 1, out_ch = 128, dim = 32, dropout=0.5, norm_fn ='instance')

# %%
# pass through encoder

enc_output = model_encoder(frames)
print('Encoder')
print(f'input shape: {frames.shape}')
print(f'output shape: {enc_output.shape}')
# Out:
# Encoder
# input shape: torch.Size([1, 15, 1, 800, 768])
# output shape: torch.Size([1, 15, 128, 200, 192])

# %% [markdown]
# ## 2. Patch extraction test
#
# - Key Points detection
# - Patch extraction (features and context from neighbour pixels of key points)
# - Feature Map of whole fls frame

# %%
from src.models.patchifier import Patchifier

# %%
with open(model_config_pth, "r") as f:
    config = Box(yaml.safe_load(f))

patchifier = Patchifier(config)

# %%
# pass input sample image through patchifier module

coords, patches_f, patches_c, fmap = patchifier(frames, mode = 'harris')

print('Patchifier')
print(f'corrds shape: {coords.shape}') # coords of key points
print(f'patches features shape: {patches_f.shape}') 
print(f'patches contexts shape: {patches_c.shape}')
print(f'features map for whole frames shape: {fmap.shape}')
# Out:
# Patchifier
# corrds shape: torch.Size([1, 15, 64, 2])
# patches features shape: torch.Size([1, 15, 64, 128, 25])
# patches contexts shape: torch.Size([1, 15, 64, 384])
# features map for whole frames shape: torch.Size([1, 15, 128, 200, 192])

# %%
key_points_visu, harris_response = patchifier.get_visu(frames, coords, batch=0, frame_num=4)
print(f'key points shape: {key_points_visu.shape}')
print(f'harris_response shape: {harris_response.shape}')



fig, ax = plt.subplots(1, 2, figsize = (15,5))
fig.suptitle(f'Patchifier result.')

ax[0].set_title('Keypoints and grid')
ax[0].imshow(key_points_visu)


ax[1].set_title('Harris response')
ax[1].imshow(harris_response, cmap='magma')

plt.show()
# Out:
# key points shape: (800, 768, 3)
# harris_response shape: (800, 768)

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import torch
import numpy as np

def verify_patch_extraction(patchifier, frames, num_patches=5):
    """
    Funkcja testująca wizualnie czy Patchifier wycina poprawne fragmenty obrazu.
    Wyświetla oryginalny obraz oraz wycięte patche na osobnych wykresach.
    """
    patchifier.eval()
    with torch.no_grad():
        # Puszczamy obraz przez sieć
        coords, patches_f, patches_c, fmap = patchifier(frames, mode='harris')

    # Zakładamy, że frames ma kształt [batch, n_frames, channels, H, W]
    img = frames[0, 0, 0].cpu().numpy()
    
    # Współrzędne najlepszych patchy dla pierwszej klatki (format: [y, x])
    crd = coords[0, 0].cpu().numpy()
    
    # Parametry patcha
    p_size = patchifier.patch_size
    downsize = patchifier.downsize_factor
    
    # patches_f ma kształt [b, n, p, kanały, p_size * p_size]
    ptchs = patches_f[0, 0].cpu().numpy()

    # Zabezpieczenie, gdyby znaleziono mniej patchy niż chcemy wyświetlić
    actual_num_patches = min(num_patches, len(crd))

    # ==========================================
    # WYKRES 1: Główny obraz z ramkami
    # ==========================================
    fig_main, ax_main = plt.subplots(figsize=(8, 8))
    ax_main.imshow(img, cmap='gray')
    ax_main.set_title("FLS image with keypoints", fontsize=14)
    
    # ==========================================
    # WYKRES 2: Wycięte patche
    # ==========================================
    fig_patches, axes_patches = plt.subplots(1, actual_num_patches, figsize=(3 * actual_num_patches, 3))
    
    # Zabezpieczenie dla przypadku, gdy wyświetlamy tylko 1 patch (axes_patches nie jest listą)
    if actual_num_patches == 1:
        axes_patches = [axes_patches]
        
    for i in range(actual_num_patches):
        y, x = crd[i] 
        
        # --- Rysowanie na głównym obrazie ---
        eff_size = p_size * downsize
        top_left_x = x - (eff_size / 2)
        top_left_y = y - (eff_size / 2)
        
        rect = patches.Rectangle((top_left_x, top_left_y), eff_size, eff_size, 
                                 linewidth=2, edgecolor='red', facecolor='none')
        ax_main.add_patch(rect)
        ax_main.text(top_left_x, top_left_y - 3, str(i), color='red', fontsize=14, weight='bold')
        
        # --- Rysowanie wyciętego patcha ---
        # Uśredniamy po kanałach i zmieniamy kształt
        patch_img = ptchs[i].mean(axis=0).reshape(p_size, p_size)
        
        axes_patches[i].imshow(patch_img, cmap='viridis') 
        axes_patches[i].set_title(f"Patch {i}\n(y={y:.1f}, x={x:.1f})")
        axes_patches[i].axis('off')
        
    plt.tight_layout()
    plt.show()

# %%
batch = next(iter(train_data_loader))
frames, time, trajectory, depth = batch
verify_patch_extraction(patchifier, frames[:, :1, :, :, :], num_patches=16)
