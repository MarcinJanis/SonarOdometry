# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# [autoreload of torch.overrides failed: Traceback (most recent call last):
#   File "c:\Users\janis\miniconda3\envs\def\Lib\site-packages\IPython\extensions\autoreload.py", line 325, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\janis\miniconda3\envs\def\Lib\site-packages\IPython\extensions\autoreload.py", line 580, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "c:\Users\janis\miniconda3\envs\def\Lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 621, in _exec
#   File "<frozen importlib._bootstrap_external>", line 940, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "c:\Users\janis\miniconda3\envs\def\Lib\site-packages\torch\overrides.py", line 1591, in <module>
#     has_torch_function = _add_docstr(
#                          ^^^^^^^^^^^^
# RuntimeError: function '_has_torch_function' already has a docstring
# ]
# [autoreload of torch._tensor failed: Traceback (most recent call last):
#   File "c:\Users\janis\miniconda3\envs\def\Lib\site-packages\IPython\extensions\autoreload.py", line 325, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\janis\miniconda3\envs\def\Lib\site-packages\IPython\extensions\autoreload.py", line 580, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "c:\Users\janis\miniconda3\envs\def\Lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 621, in _exec
#   File "<frozen importlib._bootstrap_external>", line 940, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "c:\Users\janis\miniconda3\envs\def\Lib\site-packages\torch\_tensor.py", line 81, in <module>
#     class Tensor(torch._C._TensorBase):
#   File "c:\Users\janis\miniconda3\envs\def\Lib\site-packages\torch\_tensor.py", line 630, in Tensor
#     detach = _C._add_docstr(
#              ^^^^^^^^^^^^^^^
# RuntimeError: method 'detach' already has a docstring
# ]
# [autoreload of torch.storage failed: Traceback (most recent call last):
#   File "c:\Users\janis\miniconda3\envs\def\Lib\site-packages\IPython\extensions\autoreload.py", line 325, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\janis\miniconda3\envs\def\Lib\site-packages\IPython\extensions\autoreload.py", line 621, in superreload
#     update_generic(old_obj, new_obj)
#   File "c:\Users\janis\miniconda3\envs\def\Lib\site-packages\IPython\extensions\autoreload.py", line 447, in update_generic
#     update(a, b)
#   File "c:\Users\janis\miniconda3\envs\def\Lib\site-packages\IPython\extensions\autoreload.py", line 415, in update_class
#     update_instances(old, new)
#   File "c:\Users\janis\miniconda3\envs\def\Lib\site-packages\IPython\extensions\autoreload.py", line 373, in update_instances
#     object.__setattr__(ref, "__class__", new)
# TypeError: can't apply this __setattr__ to _LegacyStorageMeta object
# ]
# [autoreload of torch.cuda.memory failed: Traceback (most recent call last):
#   File "c:\Users\janis\miniconda3\envs\def\Lib\site-packages\IPython\extensions\autoreload.py", line 325, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\janis\miniconda3\envs\def\Lib\site-packages\IPython\extensions\autoreload.py", line 621, in superreload
#     update_generic(old_obj, new_obj)
#   File "c:\Users\janis\miniconda3\envs\def\Lib\site-packages\IPython\extensions\autoreload.py", line 447, in update_generic
#     update(a, b)
#   File "c:\Users\janis\miniconda3\envs\def\Lib\site-packages\IPython\extensions\autoreload.py", line 359, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: memory_cached() requires a code object with 4 free vars, not 2671469658112
# ]
# [autoreload of torch.cuda.amp.autocast_mode failed: Traceback (most recent call last):
#   File "c:\Users\janis\miniconda3\envs\def\Lib\site-packages\IPython\extensions\autoreload.py", line 325, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\janis\miniconda3\envs\def\Lib\site-packages\IPython\extensions\autoreload.py", line 580, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "c:\Users\janis\miniconda3\envs\def\Lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 621, in _exec
#   File "<frozen importlib._bootstrap_external>", line 940, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "c:\Users\janis\miniconda3\envs\def\Lib\site-packages\torch\cuda\amp\autocast_mode.py", line 17, in <module>
#     class autocast(torch.amp.autocast_mode.autocast):
#                    ^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: module 'torch.amp' has no attribute 'autocast_mode'
# ]
# [autoreload of torch.cuda.amp.grad_scaler failed: Traceback (most recent call last):
#   File "c:\Users\janis\miniconda3\envs\def\Lib\site-packages\IPython\extensions\autoreload.py", line 325, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\janis\miniconda3\envs\def\Lib\site-packages\IPython\extensions\autoreload.py", line 621, in superreload
#     update_generic(old_obj, new_obj)
#   File "c:\Users\janis\miniconda3\envs\def\Lib\site-packages\IPython\extensions\autoreload.py", line 447, in update_generic
#     update(a, b)
#   File "c:\Users\janis\miniconda3\envs\def\Lib\site-packages\IPython\extensions\autoreload.py", line 399, in update_class
#     if update_generic(old_obj, new_obj):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\janis\miniconda3\envs\def\Lib\site-packages\IPython\extensions\autoreload.py", line 447, in update_generic
#     update(a, b)
#   File "c:\Users\janis\miniconda3\envs\def\Lib\site-packages\IPython\extensions\autoreload.py", line 359, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 4 free vars, not 2671469658112
# ]
# [autoreload of torch.cuda failed: Traceback (most recent call last):
#   File "c:\Users\janis\miniconda3\envs\def\Lib\site-packages\IPython\extensions\autoreload.py", line 325, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\janis\miniconda3\envs\def\Lib\site-packages\IPython\extensions\autoreload.py", line 580, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "c:\Users\janis\miniconda3\envs\def\Lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 621, in _exec
#   File "<frozen importlib._bootstrap_external>", line 940, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "c:\Users\janis\miniconda3\envs\def\Lib\site-packages\torch\cuda\__init__.py", line 252, in <module>
#     OutOfMemoryError = torch._C._OutOfMemoryError
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: module 'torch._C' has no attribute '_OutOfMemoryError'
# ]
# [autoreload of torch.sparse failed: Traceback (most recent call last):
#   File "c:\Users\janis\miniconda3\envs\def\Lib\site-packages\IPython\extensions\autoreload.py", line 325, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\janis\miniconda3\envs\def\Lib\site-packages\IPython\extensions\autoreload.py", line 580, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "c:\Users\janis\miniconda3\envs\def\Lib\importlib\__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 621, in _exec
#   File "<frozen importlib._bootstrap_external>", line 940, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "c:\Users\janis\miniconda3\envs\def\Lib\site-packages\torch\sparse\__init__.py", line 34, in <module>
#     addmm = _add_docstr(_sparse._sparse_addmm, r"""
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# RuntimeError: function '_sparse_addmm' already has a docstring
# ]
# [autoreload of torch.nn.parameter failed: Traceback (most recent call last):
#   File "c:\Users\janis\miniconda3\envs\def\Lib\site-packages\IPython\extensions\autoreload.py", line 325, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\janis\miniconda3\envs\def\Lib\site-packages\IPython\extensions\autoreload.py", line 621, in superreload
#     update_generic(old_obj, new_obj)
#   File "c:\Users\janis\miniconda3\envs\def\Lib\site-packages\IPython\extensions\autoreload.py", line 447, in update_generic
#     update(a, b)
#   File "c:\Users\janis\miniconda3\envs\def\Lib\site-packages\IPython\extensions\autoreload.py", line 415, in update_class
#     update_instances(old, new)
#   File "c:\Users\janis\miniconda3\envs\def\Lib\site-packages\IPython\extensions\autoreload.py", line 373, in update_instances
#     object.__setattr__(ref, "__class__", new)
# TypeError: can't apply this __setattr__ to _ParameterMeta object
# ]
# [autoreload of torch._prims_common failed: Traceback (most recent call last):
#   File "c:\Users\janis\miniconda3\envs\def\Lib\site-packages\IPython\extensions\autoreload.py", line 325, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\janis\miniconda3\envs\def\Lib\site-packages\IPython\extensions\autoreload.py", line 621, in superreload
#     update_generic(old_obj, new_obj)
#   File "c:\Users\janis\miniconda3\envs\def\Lib\site-packages\IPython\extensions\autoreload.py", line 447, in update_generic
#     update(a, b)
#   File "c:\Users\janis\miniconda3\envs\def\Lib\site-packages\IPython\extensions\autoreload.py", line 359, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: check() requires a code object with 4 free vars, not 2671469658112
# ]
# c:\Users\janis\miniconda3\envs\def\Lib\site-packages\IPython\extensions\autoreload.py:526: FutureWarning: `torch.distributed.reduce_op` is deprecated, please use `torch.distributed.ReduceOp` instead
#   in_module = hasattr(obj, "__module__") and obj.__module__ == module.__name__
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import os
import sys

import cv2

import numpy as np 

import torch
import torch.nn as nn
import torch.nn.functional as F

from box import Box
import yaml

import matplotlib.pyplot as plt

from scipy.spatial.transform import Rotation as R
import random 

import time 

root_dir = os.path.abspath('../..')
if root_dir not in sys.path:
    sys.path.append(root_dir)

from src.models.graph_inference import Graph as Graph_interference
from src.models.graph_training import Graph as Graph_train

# from src.data_loader.transforms_numpy import polar2cartesian, addSpeckleNoise, energyLoss, addBandReflects

# %% [markdown]
# - Create instances of graphs
# - Load config files

# %%
model_config_pth = 'C:/Users/janis/Projekty/Magisterka/SonarOdometry/config/model.yaml'
sonar_config_pth = 'C:/Users/janis/Projekty/Magisterka/SonarOdometry/config/sonar.yaml'
train_config_pth = 'C:/Users/janis/Projekty/Magisterka/SonarOdometry/config/training.yaml'

with open(model_config_pth, "r") as f:
    model_config = Box(yaml.safe_load(f))

with open(sonar_config_pth, "r") as f:
    sonar_config = Box(yaml.safe_load(f))

with open(train_config_pth, "r") as f:
    train_config = Box(yaml.safe_load(f))


PatchGraph_i = Graph_interference(model_config, sonar_config)
PatchGraph_t = Graph_train(model_config, sonar_config, train_config)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# - prepare data

# %%
# test data 

data_pth_sim = f'C:/Users/janis/Projekty/Magisterka/SonarOdometry/data/seq_1/fls/200.png'

# read frame 
frame_sim = cv2.imread(data_pth_sim, 0)

frame_sim = frame_sim.astype(np.uint8)
frame_sim = torch.from_numpy(frame_sim) # convert to torch tensor
frame_sim = frame_sim.float().unsqueeze(0).unsqueeze(0).unsqueeze(0)


frames_inm_series = 5
batch_size = 2
t_0 = 1.0
dt = 0.5

frame_sim_b = torch.cat([frame_sim for _ in range(frames_inm_series)], axis = 1)
frame_sim_b = torch.cat([frame_sim_b for _ in range(batch_size)], axis = 0)


time_tensor = torch.tensor([t_0 + i*dt for i in range(frames_inm_series)], device = device, dtype = torch.float)
time_tensor = time_tensor.unsqueeze(0)
time_tensor = torch.cat([time_tensor for _ in range(batch_size)], dim = 0)


print('-'*80)
print(f'Input data format:')
print(f'simulated tensor shape: {frame_sim.shape}, data type: {frame_sim.dtype}')
print(f'simulated tensors batch shape: {frame_sim_b.shape}, data type: {frame_sim_b.dtype}')
print(f'time tensor: {time_tensor.shape}')
print('-'*80)
# Out:
# --------------------------------------------------------------------------------
# Input data format:
# simulated tensor shape: torch.Size([1, 1, 1, 800, 768]), data type: torch.float32
# simulated tensors batch shape: torch.Size([2, 5, 1, 800, 768]), data type: torch.float32
# time tensor: torch.Size([2, 5])
# --------------------------------------------------------------------------------

# %% [markdown]
# ## Output test

# %%
def compare_shuffled(t1, t2):
    if t1.shape != t2.shape: return False
    # Spłaszczamy do 2D (N, -1) i sortujemy wiersze leksykograficznie
    t1_f = t1.reshape(t1.size(0), -1)
    t2_f = t2.reshape(t2.size(0), -1)
    for i in range(t1_f.shape[1]-1, -1, -1):
        t1_f = t1_f[t1_f[:, i].argsort(stable=True)]
        t2_f = t2_f[t2_f[:, i].argsort(stable=True)]
    return torch.allclose(t1_f.float(), t2_f.float(), atol=1e-3)

# %%
# === traning graph === 
t_start = time.time()

poses, coords_phi = PatchGraph_t.append(frame_sim_b, time_tensor, device)
corr_t, ctx_t, source_frame_idx_t, target_frame_idx_t, patch_idx_t = PatchGraph_t.update_step(poses, coords_phi,  device)

traning_time = time.time() - t_start
# Out:
# batch size: 2. frames: 5
# debug: torch.Size([2, 5, 7])
# debug: torch.Size([10, 7])

# %%
# === inference graph === 
t_start = time.time()

b, n, c, h, w = frame_sim_b.shape
print(frame_sim_b.shape)
for batch in range(b):
    for frame_num in range(n):
        frame = frame_sim_b[batch, frame_num, :, :, :].unsqueeze(0).unsqueeze(0)
        t = time_tensor[batch, frame_num]

        PatchGraph_i.append(frame, t, device)
        corr, ctx, source_frame_idx, target_frame_idx, patch_idx = PatchGraph_i.update_step(device)

corr_i, ctx_i, source_frame_idx_i, target_frame_idx_i, patch_idx_i = corr, ctx, source_frame_idx, target_frame_idx, patch_idx
inference_time = time.time() - t_start
# Out:
# torch.Size([2, 5, 1, 800, 768])

# %%
# comparision:
print('='*80)
print(f'Time: traning: {traning_time}, inference: {inference_time}')

print(f'number if edges in traning: {corr_t.shape}')
print(f'number if edges in inference: {corr_i.shape}')

output_test = []

output_test.append('Passed') if compare_shuffled(source_frame_idx_t, source_frame_idx_i) else output_test.append('Failed')
print(f'source_frame_idx test: {output_test[0]}')

output_test.append('Passed') if compare_shuffled(target_frame_idx_t, target_frame_idx_i) else output_test.append('Failed')
print(f'target_frame_idx test: {output_test[1]}')

output_test.append('Passed') if compare_shuffled(patch_idx_t, patch_idx_i) else output_test.append('Failed')
print(f'patch_idx test: {output_test[2]}')
# Out:
# ================================================================================
# Time: traning: 9.803590297698975, inference: 44.41348886489868
# number if edges in traning: torch.Size([180, 50])
# number if edges in inference: torch.Size([240, 50])
# source_frame_idx test: Failed
# target_frame_idx test: Failed
# patch_idx test: Failed

# %%
# display edges:
print(PatchGraph_i.frame_n)
for a in range(PatchGraph_i.i.shape[0]):
    # if a > 90:
    print(PatchGraph_i.i[a], PatchGraph_i.j[a])
# Out:
# 10
# tensor(0) tensor(-1)
# tensor(1) tensor(-1)
# tensor(2) tensor(-1)
# tensor(3) tensor(-1)
# tensor(4) tensor(-1)
# tensor(0) tensor(-2)
# tensor(1) tensor(-2)
# tensor(2) tensor(-2)
# tensor(3) tensor(-2)
# tensor(4) tensor(-2)
# tensor(0) tensor(-3)
# tensor(1) tensor(-3)
# tensor(2) tensor(-3)
# tensor(3) tensor(-3)
# tensor(4) tensor(-3)
# tensor(-15) tensor(0)
# tensor(-14) tensor(0)
# tensor(-13) tensor(0)
# tensor(-12) tensor(0)
# tensor(-11) tensor(0)
# tensor(-10) tensor(0)
# tensor(-9) tensor(0)
# tensor(-8) tensor(0)
# tensor(-7) tensor(0)
# tensor(-6) tensor(0)
# tensor(-5) tensor(0)
# tensor(-4) tensor(0)
# tensor(-3) tensor(0)
# tensor(-2) tensor(0)
# tensor(-1) tensor(0)
# tensor(5) tensor(0)
# tensor(6) tensor(0)
# tensor(7) tensor(0)
# tensor(8) tensor(0)
# tensor(9) tensor(0)
# tensor(5) tensor(-1)
# tensor(6) tensor(-1)
# tensor(7) tensor(-1)
# tensor(8) tensor(-1)
# tensor(9) tensor(-1)
# tensor(5) tensor(-2)
# tensor(6) tensor(-2)
# tensor(7) tensor(-2)
# tensor(8) tensor(-2)
# tensor(9) tensor(-2)
# tensor(-10) tensor(1)
# tensor(-9) tensor(1)
# tensor(-8) tensor(1)
# tensor(-7) tensor(1)
# tensor(-6) tensor(1)
# tensor(-5) tensor(1)
# tensor(-4) tensor(1)
# tensor(-3) tensor(1)
# tensor(-2) tensor(1)
# tensor(-1) tensor(1)
# tensor(0) tensor(1)
# tensor(1) tensor(1)
# tensor(2) tensor(1)
# tensor(3) tensor(1)
# tensor(4) tensor(1)
# tensor(10) tensor(1)
# tensor(11) tensor(1)
# tensor(12) tensor(1)
# tensor(13) tensor(1)
# tensor(14) tensor(1)
# tensor(10) tensor(0)
# tensor(11) tensor(0)
# tensor(12) tensor(0)
# tensor(13) tensor(0)
# tensor(14) tensor(0)
# tensor(10) tensor(-1)
# tensor(11) tensor(-1)
# tensor(12) tensor(-1)
# tensor(13) tensor(-1)
# tensor(14) tensor(-1)
# tensor(-5) tensor(2)
# tensor(-4) tensor(2)
# tensor(-3) tensor(2)
# tensor(-2) tensor(2)
# tensor(-1) tensor(2)
# tensor(0) tensor(2)
# tensor(1) tensor(2)
# tensor(2) tensor(2)
# tensor(3) tensor(2)
# tensor(4) tensor(2)
# tensor(5) tensor(2)
# tensor(6) tensor(2)
# tensor(7) tensor(2)
# tensor(8) tensor(2)
# tensor(9) tensor(2)
# tensor(15) tensor(2)
# tensor(16) tensor(2)
# tensor(17) tensor(2)
# tensor(18) tensor(2)
# tensor(19) tensor(2)
# tensor(15) tensor(1)
# tensor(16) tensor(1)
# tensor(17) tensor(1)
# tensor(18) tensor(1)
# tensor(19) tensor(1)
# tensor(15) tensor(0)
# tensor(16) tensor(0)
# tensor(17) tensor(0)
# tensor(18) tensor(0)
# tensor(19) tensor(0)
# tensor(0) tensor(3)
# tensor(1) tensor(3)
# tensor(2) tensor(3)
# tensor(3) tensor(3)
# tensor(4) tensor(3)
# tensor(5) tensor(3)
# tensor(6) tensor(3)
# tensor(7) tensor(3)
# tensor(8) tensor(3)
# tensor(9) tensor(3)
# tensor(10) tensor(3)
# tensor(11) tensor(3)
# tensor(12) tensor(3)
# tensor(13) tensor(3)
# tensor(14) tensor(3)
# tensor(20) tensor(3)
# tensor(21) tensor(3)
# tensor(22) tensor(3)
# tensor(23) tensor(3)
# tensor(24) tensor(3)
# tensor(20) tensor(2)
# tensor(21) tensor(2)
# tensor(22) tensor(2)
# tensor(23) tensor(2)
# tensor(24) tensor(2)
# tensor(20) tensor(1)
# tensor(21) tensor(1)
# tensor(22) tensor(1)
# tensor(23) tensor(1)
# tensor(24) tensor(1)
# tensor(5) tensor(4)
# tensor(6) tensor(4)
# tensor(7) tensor(4)
# tensor(8) tensor(4)
# tensor(9) tensor(4)
# tensor(10) tensor(4)
# tensor(11) tensor(4)
# tensor(12) tensor(4)
# tensor(13) tensor(4)
# tensor(14) tensor(4)
# tensor(15) tensor(4)
# tensor(16) tensor(4)
# tensor(17) tensor(4)
# tensor(18) tensor(4)
# tensor(19) tensor(4)
# tensor(25) tensor(4)
# tensor(26) tensor(4)
# tensor(27) tensor(4)
# tensor(28) tensor(4)
# tensor(29) tensor(4)
# tensor(25) tensor(3)
# tensor(26) tensor(3)
# tensor(27) tensor(3)
# tensor(28) tensor(3)
# tensor(29) tensor(3)
# tensor(25) tensor(2)
# tensor(26) tensor(2)
# tensor(27) tensor(2)
# tensor(28) tensor(2)
# tensor(29) tensor(2)
# tensor(10) tensor(5)
# tensor(11) tensor(5)
# tensor(12) tensor(5)
# tensor(13) tensor(5)
# tensor(14) tensor(5)
# tensor(15) tensor(5)
# tensor(16) tensor(5)
# tensor(17) tensor(5)
# tensor(18) tensor(5)
# tensor(19) tensor(5)
# tensor(20) tensor(5)
# tensor(21) tensor(5)
# tensor(22) tensor(5)
# tensor(23) tensor(5)
# tensor(24) tensor(5)
# tensor(30) tensor(5)
# tensor(31) tensor(5)
# tensor(32) tensor(5)
# tensor(33) tensor(5)
# tensor(34) tensor(5)
# tensor(30) tensor(4)
# tensor(31) tensor(4)
# tensor(32) tensor(4)
# tensor(33) tensor(4)
# tensor(34) tensor(4)
# tensor(30) tensor(3)
# tensor(31) tensor(3)
# tensor(32) tensor(3)
# tensor(33) tensor(3)
# tensor(34) tensor(3)
# tensor(15) tensor(6)
# tensor(16) tensor(6)
# tensor(17) tensor(6)
# tensor(18) tensor(6)
# tensor(19) tensor(6)
# tensor(20) tensor(6)
# tensor(21) tensor(6)
# tensor(22) tensor(6)
# tensor(23) tensor(6)
# tensor(24) tensor(6)
# tensor(25) tensor(6)
# tensor(26) tensor(6)
# tensor(27) tensor(6)
# tensor(28) tensor(6)
# tensor(29) tensor(6)
# tensor(35) tensor(6)
# tensor(36) tensor(6)
# tensor(37) tensor(6)
# tensor(38) tensor(6)
# tensor(39) tensor(6)
# tensor(35) tensor(5)
# tensor(36) tensor(5)
# tensor(37) tensor(5)
# tensor(38) tensor(5)
# tensor(39) tensor(5)
# tensor(35) tensor(4)
# tensor(36) tensor(4)
# tensor(37) tensor(4)
# tensor(38) tensor(4)
# tensor(39) tensor(4)
# tensor(20) tensor(7)
# tensor(21) tensor(7)
# tensor(22) tensor(7)
# tensor(23) tensor(7)
# tensor(24) tensor(7)
# tensor(25) tensor(7)
# tensor(26) tensor(7)
# tensor(27) tensor(7)
# tensor(28) tensor(7)
# tensor(29) tensor(7)
# tensor(30) tensor(7)
# tensor(31) tensor(7)
# tensor(32) tensor(7)
# tensor(33) tensor(7)
# tensor(34) tensor(7)
# tensor(40) tensor(7)
# tensor(41) tensor(7)
# tensor(42) tensor(7)
# tensor(43) tensor(7)
# tensor(44) tensor(7)
# tensor(40) tensor(6)
# tensor(41) tensor(6)
# tensor(42) tensor(6)
# tensor(43) tensor(6)
# tensor(44) tensor(6)
# tensor(40) tensor(5)
# tensor(41) tensor(5)
# tensor(42) tensor(5)
# tensor(43) tensor(5)
# tensor(44) tensor(5)
# tensor(25) tensor(8)
# tensor(26) tensor(8)
# tensor(27) tensor(8)
# tensor(28) tensor(8)
# tensor(29) tensor(8)
# tensor(30) tensor(8)
# tensor(31) tensor(8)
# tensor(32) tensor(8)
# tensor(33) tensor(8)
# tensor(34) tensor(8)
# tensor(35) tensor(8)
# tensor(36) tensor(8)
# tensor(37) tensor(8)
# tensor(38) tensor(8)
# tensor(39) tensor(8)
# tensor(45) tensor(8)
# tensor(46) tensor(8)
# tensor(47) tensor(8)
# tensor(48) tensor(8)
# tensor(49) tensor(8)
# tensor(45) tensor(7)
# tensor(46) tensor(7)
# tensor(47) tensor(7)
# tensor(48) tensor(7)
# tensor(49) tensor(7)
# tensor(45) tensor(6)
# tensor(46) tensor(6)
# tensor(47) tensor(6)
# tensor(48) tensor(6)
# tensor(49) tensor(6)
# tensor(30) tensor(9)
# tensor(31) tensor(9)
# tensor(32) tensor(9)
# tensor(33) tensor(9)
# tensor(34) tensor(9)
# tensor(35) tensor(9)
# tensor(36) tensor(9)
# tensor(37) tensor(9)
# tensor(38) tensor(9)
# tensor(39) tensor(9)
# tensor(40) tensor(9)
# tensor(41) tensor(9)
# tensor(42) tensor(9)
# tensor(43) tensor(9)
# tensor(44) tensor(9)

# %%
output = PatchGraph_i.visu_data(source_frame_idx_i, target_frame_idx_i, patch_idx_i)

for i, rec in enumerate(output):
    id, frames, coords = rec
    print(f'id: {id}, frames: {frames.shape}, coords: {coords.shape}')
    # print(f'Patch: {i}. Id: {id}. Occurance: {frames.shape[0]}')
    # for j in range(frames.shape[0]):
    #     print(f'    In frame: {frames[i]}, coords: {coords[i,:]}')
# Out:
# id: 35, frames: torch.Size([3]), coords: torch.Size([3, 3])
# id: 36, frames: torch.Size([3]), coords: torch.Size([3, 3])
# id: 37, frames: torch.Size([3]), coords: torch.Size([3, 3])
# id: 38, frames: torch.Size([3]), coords: torch.Size([3, 3])
# id: 39, frames: torch.Size([3]), coords: torch.Size([3, 3])
# id: 40, frames: torch.Size([3]), coords: torch.Size([3, 3])
# id: 41, frames: torch.Size([3]), coords: torch.Size([3, 3])
# id: 42, frames: torch.Size([3]), coords: torch.Size([3, 3])
# id: 43, frames: torch.Size([3]), coords: torch.Size([3, 3])
# id: 44, frames: torch.Size([3]), coords: torch.Size([3, 3])
# id: 45, frames: torch.Size([3]), coords: torch.Size([3, 3])
# id: 46, frames: torch.Size([3]), coords: torch.Size([3, 3])
# id: 47, frames: torch.Size([3]), coords: torch.Size([3, 3])
# id: 48, frames: torch.Size([3]), coords: torch.Size([3, 3])
# id: 49, frames: torch.Size([3]), coords: torch.Size([3, 3])

# %%
from src.models.update import Update 

UpdateMOdule = Update(model_cfg=model_config)


output = UpdateMOdule()
